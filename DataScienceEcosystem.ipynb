# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# #### Hay un total de 25 puntos posibles para este proyecto final.
#
# ## Su calificación se basará en los siguientes Ejercicios:

# %% [markdown]
# ### Ejercicio 2 - Cree una celda markdown con el título del cuaderno. (1 pto)

# %% [markdown]
# # DataScienceEcosystem

# %% [markdown]
# ### Ejercicio 3 - Cree una celda markdown para una introducción. (1 pto)

# %% [markdown]
# #### INTRODUCCIÓN
# Este curso le ha introducido en múltiples herramientas de la ciencia de datos y, en este proyecto final, utilizará Jupyterlite Notebook, una de las herramientas más fáciles de compartir públicamente.
#
# Aprovechando Jupyterlite Notebook en los laboratorios de Skills Network, creará su cuaderno Jupyterlite (en inglés) y lo compartirá a través de un enlace público de GitHub.
#
# OBS: En base a todas las preguntas en españl se mantendrá este idioma en todas las respuestas

# %% [markdown]
# ### Ejercicio 4 - Cree una celda markdown para enumerar los lenguajes de la ciencia de datos. (3 ptos)

# %% [markdown]
# 1.- Python
#
# 2.- R
#
# 3.- SQL
#
# 4.- Java
#
# 5.- Julia
#
# 6.- C/C++
#
# 7.- JavaScript

# %% [markdown]
# ### Ejercicio 5 - Cree una celda markdown para listar bibliotecas de ciencia de datos. (3 ptos)

# %% [markdown]
# 1.- NumPy
#
# 2.- Pandas
#
# 3.- Matplotlib
#
# 4.- Seaborn
#
# 5.- Plotly
#
# 6.- Scikit-Learn

# %% [markdown]
# ### Ejercicio 6 - Cree una celda markdown con una tabla de herramientas de Ciencia de Datos. (3 ptos)

# %% [markdown]
# | Herramientas de Ciencia de Datos |
# |----------------------------------|
# | Jupyter Notebook                 |
# | Spyder                           |
# | RStudio                          |
# | Apache Spark                     |

# %% [markdown]
# ### Ejercicio 7 - Cree una celda markdown introduciendo ejemplos de expresiones aritméticas. (1 pto)

# %% [markdown]
# # Esta es expresión aritmética
#
# (5*2)+1

# %% [markdown]
# ### Ejercicio 8 - Cree una celda de códigopara multiplicar y sumar números. (2 ptos)

# %%
(5*2)+1
# Out:
# 11

# %% [markdown]
# ### Ejercicio 9 - Cree una celda de código para convertir minutos en horas. (2 ptos)

# %%
minutos = 180
horas = minutos / 60
print(horas)
# Out:
# 3.0

# %% [markdown]
# ### Ejercicio 10 -Inserte una celda de código para listar Objetivos. (3 pts)

# %%
Objetivos = ['Utilizar markdow', 'Crear codigos aritméticos', 'Crear Listas']
print("LISTA DE OBJETIVOS")
print(Objetivos)
# Out:
# LISTA DE OBJETIVOS
# ['Utilizar markdow', 'Crear codigos aritméticos', 'Crear Listas']

# %% [markdown]
# ### Ejercicio 11 - Cree una celda markdown para indicar el nombre del Autor. (2 ptos)

# %% [markdown]
# # AUTOR: Pablo Oehncker

# %% [markdown]
# ### Ejercicio 12 - Comparta su cuaderno a través de GitHub (3 pts)

# %% [markdown]
# ### Ejercicio 13 - Haga una captura de pantalla de la primera página del cuaderno. (1 pto)

# %% [markdown]
# ![imagen.png](attachment:7d987672-92fb-450d-8e5f-194c3be218b7.png)
